# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

pd.pandas.set_option('display.max_columns', None)

# %%
df_house =pd.read_csv("test.csv")
df_house.head(10)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
# 5  1466          60       RL         75.0    10000   Pave   NaN      IR1
# 6  1467          20       RL          NaN     7980   Pave   NaN      IR1
# 7  1468          60       RL         63.0     8402   Pave   NaN      IR1
# 8  1469          20       RL         85.0    10176   Pave   NaN      Reg
# 9  1470          20       RL         70.0     8400   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# ...

# %%
ft_drop = [ft for ft in df_house.columns if df_house[ft].isnull().mean()>0.60 ]
for ft in ft_drop:
    df_house = df_house.drop(ft, axis=1)

# %% [markdown]
# # Missing Values

# %%
#Categorical Features
ft_nan= [ft for ft in df_house.columns if df_house[ft].dtypes=="O" and df_house[ft].isnull().sum()>1]
for ft in ft_nan:
    print("{}:{}".format(ft, np.round(df_house[ft].isnull().mean(),2)))
# Out:
# MSZoning:0.0
# Utilities:0.0
# MasVnrType:0.01
# BsmtQual:0.03
# BsmtCond:0.03
# BsmtExposure:0.03
# BsmtFinType1:0.03
# BsmtFinType2:0.03
# Functional:0.0
# FireplaceQu:0.5
# GarageType:0.05
# GarageFinish:0.05
# GarageQual:0.05
# GarageCond:0.05

# %%
def fill_na(df_house, ft_nan):
    df= df_house.copy()
    df[ft_nan] = df[ft_nan].fillna(df_house[ft].mode()[0])
    return df
df_house = fill_na(df_house, ft_nan)
df_house[ft_nan].isnull().mean()
# Out:
# MSZoning        0.0
# Utilities       0.0
# MasVnrType      0.0
# BsmtQual        0.0
# BsmtCond        0.0
# BsmtExposure    0.0
# BsmtFinType1    0.0
# BsmtFinType2    0.0
# Functional      0.0
# FireplaceQu     0.0
# GarageType      0.0
# GarageFinish    0.0
# GarageQual      0.0
# GarageCond      0.0
# dtype: float64

# %%
num_nan = [ft for ft in df_house.columns if df_house[ft].dtypes!="O" and df_house[ft].isnull().sum()>1]

for ft in num_nan:
    print("{}:{}".format(ft, np.round(df_house[ft].isnull().mean(),2)))
# Out:
# LotFrontage:0.16
# MasVnrArea:0.01
# BsmtFullBath:0.0
# BsmtHalfBath:0.0
# GarageYrBlt:0.05

# %%
for ft in num_nan:
    median_val = df_house[ft].median()    
    #create a new column in dataset to capture nan values
    #df_house[ft+"nan"] = np.where(df_house[ft].isnull(),1 ,0)
    df_house.fillna(median_val, inplace= True)

df_house[num_nan].isnull().mean()
# Out:
# LotFrontage     0.0
# MasVnrArea      0.0
# BsmtFullBath    0.0
# BsmtHalfBath    0.0
# GarageYrBlt     0.0
# dtype: float64

# %%
df_house.head(10)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0  1461          20       RH         80.0    11622   Pave      Reg
# 1  1462          20       RL         81.0    14267   Pave      IR1
# 2  1463          60       RL         74.0    13830   Pave      IR1
# 3  1464          60       RL         78.0     9978   Pave      IR1
# 4  1465         120       RL         43.0     5005   Pave      IR1
# 5  1466          60       RL         75.0    10000   Pave      IR1
# 6  1467          20       RL         67.0     7980   Pave      IR1
# 7  1468          60       RL         63.0     8402   Pave      IR1
# 8  1469          20       RL         85.0    10176   Pave      Reg
# 9  1470          20       RL         70.0     8400   Pave      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# ...

# %%
#temporal features
for ft in ['YearBuilt','YearRemodAdd','GarageYrBlt']:
    df_house[ft] = df_house['YrSold']- df_house[ft]
df_house[['YearBuilt','YearRemodAdd','GarageYrBlt']].head()
# Out:
#    YearBuilt  YearRemodAdd  GarageYrBlt
# 0         49            49         49.0
# 1         52            52         52.0
# 2         13            12         13.0
# 3         12            12         12.0
# 4         18            18         18.0

# %% [markdown]
# # Numerical Values

# %%
#to handle skewness
import numpy as np
num_ft = ['LotFrontage', 'LotArea', '1stFlrSF', 'GrLivArea']
for ft in num_ft:
    df_house[ft] = np.log(df_house[ft])
df_house.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage   LotArea Street LotShape  \
# 0  1461          20       RH     4.382027  9.360655   Pave      Reg
# 1  1462          20       RL     4.394449  9.565704   Pave      IR1
# 2  1463          60       RL     4.304065  9.534595   Pave      IR1
# 3  1464          60       RL     4.356709  9.208138   Pave      IR1
# 4  1465         120       RL     3.761200  8.518193   Pave      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     1Story            5            6         49
# ...

# %% [markdown]
# **Rare Categorical Features-> less than 1%**

# %%
cat_ft = [ft for ft in df_house.columns if df_house[ft].dtypes=="O"]
for ft in cat_ft:
    temp = df_house.groupby(ft)['Id'].count()/len(df_house)
    #if my temp percentage is less than 1 only then i would take that particular index
    temp_df = temp[temp>0.01].index
    #creating a new label for those categories which are less than 1%
    df_house[ft]= np.where(df_house[ft].isin(temp_df), df_house[ft], 'Rare_var')

# %%
df_house
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage   LotArea Street LotShape  \
# 0     1461          20  Rare_var     4.382027  9.360655   Pave      Reg
# 1     1462          20        RL     4.394449  9.565704   Pave      IR1
# 2     1463          60        RL     4.304065  9.534595   Pave      IR1
# 3     1464          60        RL     4.356709  9.208138   Pave      IR1
# 4     1465         120        RL     3.761200  8.518193   Pave      IR1
# ...    ...         ...       ...          ...       ...    ...      ...
# 1454  2915         160        RM     3.044522  7.568379   Pave      Reg
# 1455  2916         160        RM     3.044522  7.546446   Pave      Reg
# 1456  2917          20        RL     5.075174  9.903488   Pave      Reg
# 1457  2918          85        RL     4.127134  9.253496   Pave      Reg
# 1458  2919          60        RL     4.304065  9.172327   Pave      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
# for ft in cat_ft:
#     labels_ordered=df_house.groupby([ft])['Id'].mean().sort_values().index
#     labels_ordered={k:i for i,k in enumerate(labels_ordered,0)}
#     df_house[ft]=df_house[ft].map(labels_ordered)

# %%
# #feature scaling
# ft_scale=[feature for feature in df_house.columns if feature not in ['Id']]
# from sklearn.preprocessing import MinMaxScaler
# scaler=MinMaxScaler()
# scaler.fit(df_house[ft_scale])

# %%
# scaler.transform(df_house[ft_scale])

# %%
# #transform train and test set and add id and salePrice variable
# data = pd.concat([df_house[['Id']].reset_index(drop=True),
#                     pd.DataFrame(scaler.transform(df_house[ft_scale]), columns= ft_scale)], axis=1)

# %%
df_house.head(10)
# Out:
#      Id  MSSubClass  MSZoning  LotFrontage   LotArea Street LotShape  \
# 0  1461          20  Rare_var     4.382027  9.360655   Pave      Reg
# 1  1462          20        RL     4.394449  9.565704   Pave      IR1
# 2  1463          60        RL     4.304065  9.534595   Pave      IR1
# 3  1464          60        RL     4.356709  9.208138   Pave      IR1
# 4  1465         120        RL     3.761200  8.518193   Pave      IR1
# 5  1466          60        RL     4.317488  9.210340   Pave      IR1
# 6  1467          20        RL     4.204693  8.984694   Pave      IR1
# 7  1468          60        RL     4.143135  9.036225   Pave      IR1
# 8  1469          20        RL     4.442651  9.227787   Pave      Reg
# 9  1470          20        RL     4.248495  9.035987   Pave      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# ...

# %%
df_house.to_csv('X_test.csv', index=False)
